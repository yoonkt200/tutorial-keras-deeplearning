# %% [markdown]
# ### Diabetes Binary Classification

# %% [markdown]
# #### 1. Import & Data Preproecessing

# %% [markdown]
# - import dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('diabetes.csv', sep=',')

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.values.shape
# Out:
# (768, 9)

# %% [markdown]
# - data preprocessing

# %%
x_train = df.values[:700, :8]
y_train = df.values[:700, 8:]
x_test = df.values[700:, :8]
y_test = df.values[700:, 8:]

# %% [markdown]
# -----

# %% [markdown]
# #### 2. Deep Neural Network for Binary Classification

# %% [markdown]
# - keras modeling

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import layers

# %%
model=Sequential()
model.add(Dense(12, activation='relu', input_dim=8))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# - learning

# %%
history = model.fit(x_train, y_train, epochs=1000, batch_size=100, validation_split=0.2, verbose=1)
performance_test = model.evaluate(x_test, y_test, batch_size=10, verbose=1)
print('Test Loss and Accuracy ->', performance_test)
# Out:
# Train on 560 samples, validate on 140 samples
# Epoch 1/1000
# 560/560 [==============================] - 0s 31us/step - loss: 0.4035 - acc: 0.8089 - val_loss: 0.6479 - val_acc: 0.7429
# Epoch 2/1000
# 560/560 [==============================] - 0s 39us/step - loss: 0.3970 - acc: 0.8196 - val_loss: 0.6146 - val_acc: 0.7857
# Epoch 3/1000
# 560/560 [==============================] - 0s 54us/step - loss: 0.3897 - acc: 0.8107 - val_loss: 0.6264 - val_acc: 0.7929
# Epoch 4/1000
# 560/560 [==============================] - 0s 48us/step - loss: 0.3896 - acc: 0.8036 - val_loss: 0.6176 - val_acc: 0.7929
# Epoch 5/1000
# 560/560 [==============================] - 0s 46us/step - loss: 0.3894 - acc: 0.8125 - val_loss: 0.6245 - val_acc: 0.8143
# Epoch 6/1000
# 560/560 [==============================] - 0s 48us/step - loss: 0.3874 - acc: 0.8179 - val_loss: 0.6301 - val_acc: 0.7857
# Epoch 7/1000
# ...

# %% [markdown]
# #### 3. Another step

# %% [markdown]
# - data scaling

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
scaled_dataset = min_max_scaler.fit_transform(df.values[:, :8])

x_train = scaled_dataset[:700, :8]
y_train = df.values[:700, 8:]
x_test = scaled_dataset[700:, :8]
y_test = df.values[700:, 8:]

# %%
model=Sequential()
model.add(Dense(12, activation='relu', input_dim=8))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=1000, batch_size=100, validation_split=0.2, verbose=1)
performance_test = model.evaluate(x_test, y_test, batch_size=10, verbose=1)
print('Test Loss and Accuracy ->', performance_test)
# Out:
# Train on 560 samples, validate on 140 samples
# Epoch 1/1000
# 560/560 [==============================] - 0s 549us/step - loss: 0.6877 - acc: 0.5625 - val_loss: 0.6844 - val_acc: 0.5857
# Epoch 2/1000
# 560/560 [==============================] - 0s 37us/step - loss: 0.6815 - acc: 0.6214 - val_loss: 0.6776 - val_acc: 0.6286
# Epoch 3/1000
# 560/560 [==============================] - 0s 38us/step - loss: 0.6759 - acc: 0.6518 - val_loss: 0.6712 - val_acc: 0.6714
# Epoch 4/1000
# 560/560 [==============================] - 0s 34us/step - loss: 0.6711 - acc: 0.6500 - val_loss: 0.6661 - val_acc: 0.6714
# Epoch 5/1000
# 560/560 [==============================] - 0s 43us/step - loss: 0.6675 - acc: 0.6500 - val_loss: 0.6617 - val_acc: 0.6714
# Epoch 6/1000
# 560/560 [==============================] - 0s 49us/step - loss: 0.6640 - acc: 0.6518 - val_loss: 0.6580 - val_acc: 0.6714
# Epoch 7/1000
# ...

# %% [markdown]
# ### result
# - Deep Neural Network & Feature scaling works well !!
